# %%
import csv
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

def weightingTFIDF(username):
    term = []

    infile = "dataset/process/processed-tweets-@" + username + ".csv"
    with open(infile, 'r') as file:
        i = 0
        tweets = []
        for row in file:
            if i == 0:
                i += 1
                continue
            row = row.split(',')[1]
            row = row.split('\n')[0]
            tweets.append(row)
        term = ' '.join(tweets)

    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform([term])
    feature_names = vectorizer.get_feature_names()
    dense = vectors.todense()
    denselist = dense.tolist()

    outfile = "dataset/weight/tfidf-tweets-@" + username + ".csv"
    with open(outfile, mode='w') as file:
        file.write('term,weight\n')
        for i in range(len(feature_names)):
            file.write(str(feature_names[i])+','+str(round(denselist[0][i], 3))+'\n')

    print("\n- writing to '" + outfile + "' complete.")

if __name__ == '__main__':
    users = ['achadianrani', 'almostbeyours', 'amarasyawalni', 'erickdidudidu', 'ferrafbryn', 'fridamayanti', 'ichatarina', 'jehademusa', 'laylarmdhnaa', 'lenoydew', 'liawrdhani', 'munawaroh_mona', 'nysmonworld', 'shafiraara', 'siti_sr137', '9ita7unn', '_avocada', '_chaendelier_', '_marfami', '_nilazka', '_sylvialestari', 'a2lir', 'abcdenjiii', 'adamumemo', 'adewiana14', 'adindahapsa', 'adityalinardi', 'adityandr', 'adityosusanto_', 'adlfynf', 'adorablejuneya', 'adputri_', 'afidazkyy', 'agus_trianto', 'aisyahafr', 'aiuchida', 'akhsaraa', 'akuuuberuang', 'alaaini1', 'alaniafitri', 'aldimaulana48', 'alfian_ay', 'alfinalfinn', 'alfrisadivaw', 'aliencuk', 'alifahdellaf', 'alitapuspa_', 'amalianadiene', 'amandapht', 'amhryn', 'amindwiananda', 'ana_ot', 'anakyangtangkas', 'andiniayu', 'andrisuartikaa', 'anggycaa', 'anissa_sani', 'anzjani', 'apaanmanggil', 'apdesti_', 'arangkecap', 'ardianitaap', 'ariefpopoh', 'arindyaf', 'arisetiyani12', 'arizamarine', 'arrrasseo', 'artikakristi', 'asriyahasry', 'astikhairunnisa', 'astridvivianni', 'astrifaj', 'ath_tobe', 'athayaanabila', 'attamufid', 'auliapramudya_', 'avidazr', 'awwlltl', 'ayrachma', 'azharizkita', 'azwardfauzan', 'baksopangsitnya', 'bananamilxxx', 'belfiani', 'benrskbyg', 'bestchrysalis', 'bettyindahr', 'betyratih', 'bibblegumm_', 'bintangphy', 'biyaanhaz', 'bodoamatbrou', 'borahyungg', 'brilliaflah', 'bukandove', 'bukanrohalia', 'bvdztkvlr', 'canc_ers', 'ccarenth', 'chandnidevi', 'chndooy', 'chtime__', 'chyntw_', 'cipipiw', 'citora_', 'claraang09', 'classmlild', 'copcopiaa', 'crysandh', 'dafugmbah', 'dalgonasachet', 'dannytandean', 'daranagas', 'darna17', 'dartina_', 'deliahndt', 'dellapj_', 'dennisransun', 'denokdhena', 'destaard', 'destandriyani', 'destychaniaa', 'detiaferlian', 'devia_riskaa', 'dewirossilia', 'dheaniranabila', 'dikmabelarosa', 'diniheryani', 'dippp_p', 'ditdandep', 'dsnmld', 'duwaaaay', 'dwiahkam', 'dwidys_', 'dwraoktavia', 'dyeah13', 'dzakimadhani', 'dzakyhaidar__', 'effendisgurl', 'egabetari', 'ejakulasi_', 'ekahanda', 'elidoff', 'emanggemeshin', 'erisyaeris', 'ervhans', 'esjaeruk', 'estlrsty', 'evaxevi', 'eyaaaxx', 'fadfadholic', 'fanirchm27', 'farahmhdyyh', 'febrianirevita', 'fia_lutfiazhari', 'fildzahanais', 'finaihsani', 'firda0305', 'firdahanifa_', 'firstyfelanda', 'fitriindy', 'fitrisip', 'g1tsy', 'ghias_yusuf', 'gieskalaila', 'gorjesparkle', 'gramelt', 'granweastery', 'greeniscalming', 'grestina', 'griffitpypiet', 'gthagrace', 'gustianarii', 'h3llatrash', 'haluhaluclubbb', 'hani_ristiawan', 'hapsarihn', 'hasinanr', 'hawaariyy', 'hazizaanifa', 'hermajestyrania', 'heyhestyy', 'hidadahida', 'hkawilarangg', 'hlutami', 'husnavinaa', 'hypertenshit', 'i_frankenstein', 'ibnubons', 'idrisg8', 'iffamee', 'iftitahptr', 'ikhwaaaaann', 'ilma678', 'imaashoima', 'imadamii', 'imfnia', 'indahastikas', 'inditarizky', 'indraszlaila', 'indrayyyy_', 'inesprat_', 'inkafbrn', 'innocentpep', 'intansakina28', 'introperti', 'iqbalpaz', 'ireenarum', 'isnakhairi', 'itshardys', 'ivyeol', 'januarrmdhn', 'joabaldo', 'joeniararief', 'jollajoly', 'juliandennis1', 'juliepuspita01', 'jundie_m', 'jusrambai', 'juwitasdrman', 'kalisnakal', 'kasurjalan', 'kasurlante', 'kawaipuna_', 'keiziasyf', 'kepikbesar', 'kerakteloorr', 'kharismagpri', 'khelian_ni_s', 'ki_cuu', 'kimsatgat2', 'kirannaurora', 'kodelle_', 'kokocrvnch', 'komalasari_ak', 'krisnawah', 'kucingsmanda_', 'kumanokabe_', 'ladafiq', 'lailapurnamas', 'lalenamanoban', 'latifanajla__', 'latifasyf', 'leoagung98', 'lerinarin', 'liawatii_', 'liayurh_', 'liestianoviani', 'linggaralfi', 'liputarinns', 'llakhr', 'lulufrdni', 'marisahafsyah94', 'maulanariandi', 'mautongue', 'megapsmr', 'mellamotis', 'melyst94', 'meniaclosia', 'messylusmitha', 'metinaayu_', 'micinsassae', 'miftahulilma10', 'mininoenk', 'msyitams', 'muthiaf10', 'nabilatunss', 'nadhira42', 'nadiadjibran', 'nadihng', 'nadyaulfahn', 'nailazulfanz', 'nanasambara', 'nanuazz', 'nauli_permata', 'nevienpan', 'niazmi_', 'nidakarin', 'nneninot1996', 'nopiynovi', 'normalvira', 'novia_pqr', 'novitakurniap', 'novitnurul', 'nstlstnngrm', 'nurulainiii', 'nwindaputri', 'ociirosiana', 'okkyskripsi', 'okyranda', 'oneperson01_', 'ovilsp', 'owkowkok', 'oziechonky', 'pelangikecilll', 'phoebee_ip', 'pinchipowww', 'pinochiao', 'pocagurii', 'prastikavivi', 'prialitaf', 'ptorianns', 'pujaypujilpuu', 'pujisay', 'punyauname', 'puspapradinaa', 'puten_hijau', 'puteriroro', 'putriyuniardi', 'qthrnnada', 'r_fiika', 'rafitaasr', 'rahmaarindapp', 'rahmahwanti', 'rahmatfathoni', 'rallyanta', 'ramdaneinstein', 'rdtlfiqryaj', 'readytomingie', 'rianita_sm', 'rierabcd', 'risdahlbs', 'riskaadesuryani', 'rizka_christian', 'rizkaaulia', 'rizol_rizal', 'rkhusfa', 'rkismaniar', 'rohanahrey', 'rpdelimaa', 'rvghalif', 'rzqmentari', 'saccharinande', 'salisnurk', 'salsabilabia', 'saraadaay', 'sartikadesi212', 'savirapu', 'scharrii', 'seacrabble', 'sefticare', 'sekarumn', 'selftalker', 'sfaui', 'shelfiw', 'shobronabadan', 'silmiotmiot', 'silvialucyana', 'silvihoroni', 'siti89nurjanah', 'slvdys', 'sobatqasurr', 'sora_alxean', 'stephanieayuu', 'stillyourbae', 'strybycy', 'stttopp', 'sulisprstya', 'sundalaif', 'susheetrashh', 'susiindah16', 'syifa_syifo', 't_gooners16', 't_hndr', 'tahtaallfina', 'taritahir', 'tastyducky', 'tiaraindhprmt', 'timutiimuti', 'tnrx_', 'tramadanur', 'triaisharaa', 'trisawardanis', 'ucciiill', 'ugitugitmiskoi', 'upikmera', 'ursnflwr_', 'ussiiyy', 'utho_', 'v3isvthree', 'vanillasvgar', 'viasyafiqa', 'viragutubela', 'virraaa_', 'vnyriany', 'wequte', 'wulandrshrmn', 'wydyudi_', 'yaelahir', 'yokozka', 'youcan_it', 'yovimelan', 'ysyni', 'yudkuswar', 'yulfaariza', 'yulia_danche', 'yuliawafa', 'yusrinasmarani', 'yuuta__96', 'zea_mays07']

    for user in users:
        weightingTFIDF(user)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# - writing to 'dataset/weight/tfidf-tweets-@achadianrani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@almostbeyours.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@amarasyawalni.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@erickdidudidu.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ferrafbryn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@fridamayanti.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ichatarina.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@jehademusa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@laylarmdhnaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@lenoydew.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@liawrdhani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@munawaroh_mona.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nysmonworld.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@shafiraara.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@siti_sr137.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@9ita7unn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@_avocada.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@_chaendelier_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@_marfami.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@_nilazka.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@_sylvialestari.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@a2lir.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@abcdenjiii.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@adamumemo.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@adewiana14.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@adindahapsa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@adityalinardi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@adityandr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@adityosusanto_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@adlfynf.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@adorablejuneya.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@adputri_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@afidazkyy.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@agus_trianto.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@aisyahafr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@aiuchida.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@akhsaraa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@akuuuberuang.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@alaaini1.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@alaniafitri.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@aldimaulana48.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@alfian_ay.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@alfinalfinn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@alfrisadivaw.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@aliencuk.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@alifahdellaf.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@alitapuspa_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@amalianadiene.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@amandapht.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@amhryn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@amindwiananda.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ana_ot.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@anakyangtangkas.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@andiniayu.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@andrisuartikaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@anggycaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@anissa_sani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@anzjani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@apaanmanggil.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@apdesti_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@arangkecap.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ardianitaap.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ariefpopoh.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@arindyaf.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@arisetiyani12.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@arizamarine.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@arrrasseo.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@artikakristi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@asriyahasry.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@astikhairunnisa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@astridvivianni.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@astrifaj.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ath_tobe.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@athayaanabila.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@attamufid.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@auliapramudya_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@avidazr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@awwlltl.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ayrachma.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@azharizkita.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@azwardfauzan.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@baksopangsitnya.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@bananamilxxx.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@belfiani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@benrskbyg.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@bestchrysalis.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@bettyindahr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@betyratih.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@bibblegumm_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@bintangphy.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@biyaanhaz.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@bodoamatbrou.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@borahyungg.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@brilliaflah.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@bukandove.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@bukanrohalia.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@bvdztkvlr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@canc_ers.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ccarenth.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@chandnidevi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@chndooy.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@chtime__.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@chyntw_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@cipipiw.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@citora_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@claraang09.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@classmlild.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@copcopiaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@crysandh.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dafugmbah.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dalgonasachet.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dannytandean.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@daranagas.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@darna17.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dartina_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@deliahndt.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dellapj_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dennisransun.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@denokdhena.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@destaard.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@destandriyani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@destychaniaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@detiaferlian.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@devia_riskaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dewirossilia.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dheaniranabila.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dikmabelarosa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@diniheryani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dippp_p.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ditdandep.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dsnmld.csv' complete.
# - writing to 'dataset/weight/tfidf-tweets-@duwaaaay.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dwiahkam.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dwidys_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dwraoktavia.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dyeah13.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dzakimadhani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@dzakyhaidar__.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@effendisgurl.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@egabetari.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ejakulasi_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ekahanda.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@elidoff.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@emanggemeshin.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@erisyaeris.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ervhans.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@esjaeruk.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@estlrsty.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@evaxevi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@eyaaaxx.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@fadfadholic.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@fanirchm27.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@farahmhdyyh.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@febrianirevita.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@fia_lutfiazhari.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@fildzahanais.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@finaihsani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@firda0305.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@firdahanifa_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@firstyfelanda.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@fitriindy.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@fitrisip.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@g1tsy.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ghias_yusuf.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@gieskalaila.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@gorjesparkle.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@gramelt.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@granweastery.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@greeniscalming.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@grestina.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@griffitpypiet.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@gthagrace.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@gustianarii.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@h3llatrash.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@haluhaluclubbb.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hani_ristiawan.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hapsarihn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hasinanr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hawaariyy.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hazizaanifa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hermajestyrania.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@heyhestyy.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hidadahida.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hkawilarangg.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hlutami.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@husnavinaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@hypertenshit.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@i_frankenstein.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ibnubons.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@idrisg8.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@iffamee.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@iftitahptr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ikhwaaaaann.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ilma678.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@imaashoima.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@imadamii.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@imfnia.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@indahastikas.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@inditarizky.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@indraszlaila.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@indrayyyy_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@inesprat_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@inkafbrn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@innocentpep.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@intansakina28.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@introperti.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@iqbalpaz.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ireenarum.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@isnakhairi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@itshardys.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ivyeol.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@januarrmdhn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@joabaldo.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@joeniararief.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@jollajoly.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@juliandennis1.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@juliepuspita01.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@jundie_m.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@jusrambai.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@juwitasdrman.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kalisnakal.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kasurjalan.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kasurlante.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kawaipuna_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@keiziasyf.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kepikbesar.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kerakteloorr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kharismagpri.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@khelian_ni_s.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ki_cuu.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kimsatgat2.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kirannaurora.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kodelle_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kokocrvnch.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@komalasari_ak.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@krisnawah.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kucingsmanda_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@kumanokabe_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ladafiq.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@lailapurnamas.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@lalenamanoban.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@latifanajla__.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@latifasyf.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@leoagung98.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@lerinarin.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@liawatii_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@liayurh_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@liestianoviani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@linggaralfi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@liputarinns.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@llakhr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@lulufrdni.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@marisahafsyah94.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@maulanariandi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@mautongue.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@megapsmr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@mellamotis.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@melyst94.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@meniaclosia.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@messylusmitha.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@metinaayu_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@micinsassae.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@miftahulilma10.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@mininoenk.csv' complete.
# - writing to 'dataset/weight/tfidf-tweets-@msyitams.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@muthiaf10.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nabilatunss.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nadhira42.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nadiadjibran.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nadihng.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nadyaulfahn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nailazulfanz.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nanasambara.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nanuazz.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nauli_permata.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nevienpan.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@niazmi_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nidakarin.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nneninot1996.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nopiynovi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@normalvira.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@novia_pqr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@novitakurniap.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@novitnurul.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nstlstnngrm.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nurulainiii.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@nwindaputri.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ociirosiana.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@okkyskripsi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@okyranda.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@oneperson01_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ovilsp.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@owkowkok.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@oziechonky.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@pelangikecilll.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@phoebee_ip.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@pinchipowww.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@pinochiao.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@pocagurii.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@prastikavivi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@prialitaf.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ptorianns.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@pujaypujilpuu.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@pujisay.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@punyauname.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@puspapradinaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@puten_hijau.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@puteriroro.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@putriyuniardi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@qthrnnada.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@r_fiika.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rafitaasr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rahmaarindapp.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rahmahwanti.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rahmatfathoni.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rallyanta.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ramdaneinstein.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rdtlfiqryaj.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@readytomingie.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rianita_sm.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rierabcd.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@risdahlbs.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@riskaadesuryani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rizka_christian.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rizkaaulia.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rizol_rizal.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rkhusfa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rkismaniar.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rohanahrey.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rpdelimaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rvghalif.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@rzqmentari.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@saccharinande.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@salisnurk.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@salsabilabia.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@saraadaay.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@sartikadesi212.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@savirapu.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@scharrii.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@seacrabble.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@sefticare.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@sekarumn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@selftalker.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@sfaui.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@shelfiw.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@shobronabadan.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@silmiotmiot.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@silvialucyana.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@silvihoroni.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@siti89nurjanah.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@slvdys.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@sobatqasurr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@sora_alxean.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@stephanieayuu.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@stillyourbae.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@strybycy.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@stttopp.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@sulisprstya.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@sundalaif.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@susheetrashh.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@susiindah16.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@syifa_syifo.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@t_gooners16.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@t_hndr.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@tahtaallfina.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@taritahir.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@tastyducky.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@tiaraindhprmt.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@timutiimuti.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@tnrx_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@tramadanur.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@triaisharaa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@trisawardanis.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ucciiill.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ugitugitmiskoi.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@upikmera.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ursnflwr_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ussiiyy.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@utho_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@v3isvthree.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@vanillasvgar.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@viasyafiqa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@viragutubela.csv' complete.
# - writing to 'dataset/weight/tfidf-tweets-@virraaa_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@vnyriany.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@wequte.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@wulandrshrmn.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@wydyudi_.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@yaelahir.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@yokozka.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@youcan_it.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@yovimelan.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@ysyni.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@yudkuswar.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@yulfaariza.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@yulia_danche.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@yuliawafa.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@yusrinasmarani.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@yuuta__96.csv' complete.
#
# - writing to 'dataset/weight/tfidf-tweets-@zea_mays07.csv' complete.
